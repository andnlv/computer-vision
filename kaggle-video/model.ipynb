# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
import keras
import keras.layers as L

# %%
shapes = set()

# %%
for dir in ['data/train/7414', 'data/train/8032', 'data/train/2742', 'data/train/9425']:
    for fname in os.listdir(dir):
        img = plt.imread(os.path.join(dir, fname))
        img_new = np.zeros([240, 320, 4])
        img_new[15:, :] = img[:, 40:-40]
        plt.imshow(img_new)
        plt.show()

# %%
for i, j, k in tqdm_notebook(os.walk('data/train'), total=8*len(os.listdir('data/train')) + 1):
    if len(j) == 0:
        img = plt.imread(os.path.join(i, k[0]))
        print((img[:, :, 3] == 1).all())
# Out:
# ...
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
# Out:
# {(240, 320, 4)}
